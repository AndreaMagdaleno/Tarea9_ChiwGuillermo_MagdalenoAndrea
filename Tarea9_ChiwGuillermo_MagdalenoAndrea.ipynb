# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFzQj91sOlkeDFkg5HDbjtR4QJYmLXkfMNig&usqp=CAU" width="400" height="500" />
#
#
# ### <font color='navy'> Simulación matemática.
#
# **Nombres:** Óscar Guillermo Chiw Lozano & Andrea Anai Magdaleno Cárdenas.
#
# **Fecha:** 08 de noviembre del 2023.
#
# **Expediente** : 736814 & 725822.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/Guillermo-Chiw-ITESO/Tarea9_ChiwGuillermo_MagdalenoAndrea
#
# # Tarea 9: Clase 20

# %% [markdown]
# ## **Tarea 9**. ¿Cómo se ve el espacio fase para los diferentes casos así como para diferentes condiciones iniciales?
#
# > En un gráfico como el anterior, realizar gráficas del plano fase para los distintos movimientos y para cuatro conjuntos de condiciones iniciales distintas
# - y0 = [1, 1]
# - y0 = [1, -1]
# - y0 = [-1, 1]
# - y0 = [-1, -1]
#
# Hacer lo anterior en un nuevo notebook de jupyter llamado Tarea7_ApellidoNombre.ipynb y subir en el espacio habilitado.

# %% [markdown]
# ### Ejercicio 1: (enunciado) Transcribirlo

# %% [markdown]
# # Código de solución Óscar Guillermo Chiw Lozano

# %%
# Primero importamos todas las librerias, paquetes y/o funciones que vamos a utlizar
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# Definimos los parámetros k, m y c
k, m, c = 3, 1, 0.5

# Función f(y,t) que vamos a integrar
def amortiguado(y,t,k,m,c):
    y1 = y[0]
    y2 = y[1]
    return np.array([y2, -(k/m)*y1-(c/m)*y2])

# Especificamos los puntos de tiempo donde queremos la solución
t = np.linspace(0, 30, 300)

# %% [markdown]
# ### $y_0$ = [1, 1]

# %%
# Condiciones iniciales
y0_1 = np.array([1, 1])

# Solución numérica
y_1 = odeint(amortiguado, y0_1, t, args=(k,m,c))

# Averiguar la forma de solución
y_1.shape

# Extraer y1 y y2
y1 = y_1[:,0]
y2 = y_1[:,1]

# %%
# Gráfica
omega0=(k/m)**0.5

# Gráfica del plano fase para y0 = [1, 1]
plt.figure(figsize=(8,6))
plt.plot(y1, y2/omega0, 'b', lw=3)
plt.title('Condiciones iniciales: [1, 1]')
plt.xlabel("Posición $y_1$")
plt.ylabel("Velocidad normalizada $y_2/\omega_0$")
plt.grid()
plt.show()

# %% [markdown]
# ### $y_0$ = [1, -1]

# %%
# Condiciones iniciales
y0_2 = np.array([1, -1])

# Solución numérica
y_2 = odeint(amortiguado, y0_2, t, args=(k,m,c))

# Averiguar la forma de solución
y_2.shape

# Extraer y1 y y2
y3 = y_2[:,0]
y4 = y_2[:,1]

# %%
# Gráfica
omega0=(k/m)**0.5

# Gráfica del plano fase para y0 = [1, -1]
plt.figure(figsize=(8,6))
plt.plot(y3, y4/omega0, 'r', lw=3)
plt.title('Condiciones iniciales: [1, -1]')
plt.xlabel("Posición $y_3$")
plt.ylabel("Velocidad normalizada $y_4/\omega_0$")
plt.grid()
plt.show()

# %% [markdown]
# ### $y_0$ = [-1, 1]

# %%
# Condiciones iniciales
y0_3 = np.array([-1, 1])

# Solución numérica
y_3 = odeint(amortiguado, y0_3, t, args=(k,m,c))

# Averiguar la forma de solución
y_3.shape

# Extraer y1 y y2
y5 = y_3[:,0]
y6 = y_3[:,1]

# %%
# Gráfica
omega0=(k/m)**0.5

# Gráfica del plano fase para y0 = [-1, 1]
plt.figure(figsize=(8,6))
plt.plot(y5, y6/omega0, 'g', lw=3)
plt.title('Condiciones iniciales: [-1, 1]')
plt.xlabel("Posición $y_5$")
plt.ylabel("Velocidad normalizada $y_6/\omega_0$")
plt.grid()
plt.show()

# %% [markdown]
# ### $y_0$ = [-1, -1]

# %%
# Condiciones iniciales
y0_4 = np.array([-1, -1])

# Solución numérica
y_4 = odeint(amortiguado, y0_4, t, args=(k,m,c))

# Averiguar la forma de solución
y_4.shape

# Extraer y1 y y2
y7 = y_4[:,0]
y8 = y_4[:,1]

# %%
# Gráfica
omega0=(k/m)**0.5

# Gráfica del plano fase para y0 = [-1, -1]
plt.figure(figsize=(8,6))
plt.plot(y7, y8/omega0, 'c', lw=3)
plt.title('Condiciones iniciales: [-1, -1]')
plt.xlabel("Posición $y_7$")
plt.ylabel("Velocidad normalizada $y_/\omega_0$")
plt.grid()
plt.show()

# %%
# Gráfica del plano fase para y0 = [1, 1]
plt.figure(figsize=(8,6))
plt.plot(y1, y2/omega0, 'b', lw=3)
plt.title('Condiciones iniciales: [1, 1]')
plt.xlabel("Posición $y_1$")
plt.ylabel("Velocidad normalizada $y_2/\omega_0$")
plt.grid()
plt.show()

# Gráfica del plano fase para y0 = [1, -1]
plt.figure(figsize=(8,6))
plt.plot(y3, y4/omega0, 'r', lw=3)
plt.title('Condiciones iniciales: [1, -1]')
plt.xlabel("Posición $y_3$")
plt.ylabel("Velocidad normalizada $y_4/\omega_0$")
plt.grid()
plt.show()

# Gráfica del plano fase para y0 = [-1, 1]
plt.figure(figsize=(8,6))
plt.plot(y5, y6/omega0, 'g', lw=3)
plt.title('Condiciones iniciales: [-1, 1]')
plt.xlabel("Posición $y_5$")
plt.ylabel("Velocidad normalizada $y_6/\omega_0$")
plt.grid()
plt.show()

# Gráfica del plano fase para y0 = [-1, -1]
plt.figure(figsize=(8,6))
plt.plot(y7, y8/omega0, 'c', lw=3)
plt.title('Condiciones iniciales: [-1, -1]')
plt.xlabel("Posición $y_7$")
plt.ylabel("Velocidad normalizada $y_8/\omega_0$")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 30
#      28 # Gráfica del plano fase para y0 = [-1, -1]
#      29 plt.figure(figsize=(8,6))
# ---> 30 plt.plot(y7, y8/omega0, 'c', lw=3)
#      31 plt.title('Condiciones iniciales: [-1, -1]')
#      32 plt.xlabel("Posición $y_7$")
#
# NameError: name 'y7' is not defined

# %% [markdown]
# # Código de solución Andra Anai Magdaleno Cárdenas

# %%
# Código de solución estudiante 2

# Primero importamos todas las librerias, paquetes y/o funciones que vamos a utlizar
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# ## $y_0$ = [1, 1]

# %%
# Subamortiguado

# Definimos los parámetros k, m y c
k, m, c = 3, 1, 0.5

# Función f(y,t) que vamos a integrar
def amortiguado(y,t,k,m,c):
    y1 = y[1]
    y2 = y[1]
    return np.array([y2, -(k/m)*y1-(c/m)*y2])

# Condiciones iniciales
y0 = np.array([1,1])

# Especificamos los puntos de tiempo donde queremos la solución
t = np.linspace(0, 30, 300)

# Solución numérica
y = odeint(amortiguado, y0, t, args=(k,m,c))

omega0 = (k/m)**0.5
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 > Gamma**2

# Sobreamortiguado
# Nuevas constantes 
k = .1 # Constante del muelle
m = 1.0   # Masa
c = 1 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2<Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1s = y[:,1]
y2s = y[:,1]


# Amortiguamiento crítico
# Nuevas constantes
k = .0625 # Constante del muelle
m = 1.0   # Masa
c = .5 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 == Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1c = y[:,1]
y2c = y[:,1]

# %%
tt = t
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, sharex='col',
                                                       sharey='row',figsize =(10,6))
ax1.plot(tt, y1, c = 'k') 
ax1.set_title('Amortiguado', fontsize = 14)
ax1.set_ylabel('Posición', fontsize = 14)
ax2.plot(tt, y1s, c = 'b') 
ax2.set_title('Sobreamortiguado', fontsize = 14)
ax3.plot(tt, y1c, c = 'r') 
ax3.set_title('Crítico', fontsize = 16)
ax4.plot(tt, y2, c = 'k')
ax4.set_ylabel('Velocidad', fontsize = 14)
ax4.set_xlabel('tiempo', fontsize = 14)
ax5.plot(tt, y2s, c = 'b')
ax5.set_xlabel('tiempo', fontsize = 14)
ax6.plot(tt, y2c, c = 'r')
ax6.set_xlabel('tiempo', fontsize = 14)
plt.show()

# %% [markdown]
# ## $y_0$ = [1, -1]

# %%
# Subamortiguado

# Definimos los parámetros k, m y c
k, m, c = 3, 1, 0.5

# Función f(y,t) que vamos a integrar
def amortiguado(y,t,k,m,c):
    y1a = y[1]
    y2a = y[-1]
    return np.array([y2a, -(k/m)*y1a-(c/m)*y2a])

# Condiciones iniciales
y0 = np.array([1,-1])

# Especificamos los puntos de tiempo donde queremos la solución
t = np.linspace(0, 30, 300)

# Solución numérica
y = odeint(amortiguado, y0, t, args=(k,m,c))

omega0 = (k/m)**0.5
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 > Gamma**2

# Sobreamortiguado
# Nuevas constantes 
k = .1 # Constante del muelle
m = 1.0   # Masa
c = 1 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2<Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1sa = y[:,1]
y2sa = y[:,-1]


# Amortiguamiento crítico
# Nuevas constantes
k = .0625 # Constante del muelle
m = 1.0   # Masa
c = .5 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 == Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1ca = y[:,1]
y2ca = y[:,-1]

# %%
tt = t
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, sharex='col',
                                                       sharey='row',figsize =(10,6))
ax1.plot(tt, y1a, c = 'k') 
ax1.set_title('Amortiguado', fontsize = 14)
ax1.set_ylabel('Posición', fontsize = 14)
ax2.plot(tt, y1sa, c = 'b') 
ax2.set_title('Sobreamortiguado', fontsize = 14)
ax3.plot(tt, y1ca, c = 'r') 
ax3.set_title('Crítico', fontsize = 16)
ax4.plot(tt, y2a, c = 'k')
ax4.set_ylabel('Velocidad', fontsize = 14)
ax4.set_xlabel('tiempo', fontsize = 14)
ax5.plot(tt, y2sa, c = 'b')
ax5.set_xlabel('tiempo', fontsize = 14)
ax6.plot(tt, y2ca, c = 'r')
ax6.set_xlabel('tiempo', fontsize = 14)
plt.show()

# %% [markdown]
# ## $y_0$ = [-1, 1]

# %%
# Subamortiguado

# Definimos los parámetros k, m y c
k, m, c = 3, 1, 0.5

# Función f(y,t) que vamos a integrar
def amortiguado(y,t,k,m,c):
    y1 = y[-1]
    y2 = y[1]
    return np.array([y2, -(k/m)*y1-(c/m)*y2])

# Condiciones iniciales
y0 = np.array([-1,1])

# Especificamos los puntos de tiempo donde queremos la solución
t = np.linspace(0, 30, 300)

# Solución numérica
y = odeint(amortiguado, y0, t, args=(k,m,c))

omega0 = (k/m)**0.5
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 > Gamma**2

# Sobreamortiguado
# Nuevas constantes 
k = .1 # Constante del muelle
m = 1.0   # Masa
c = 1 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2<Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1s = y[:,-1]
y2s = y[:,1]


# Amortiguamiento crítico
# Nuevas constantes
k = .0625 # Constante del muelle
m = 1.0   # Masa
c = .5 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 == Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1c = y[:,-1]
y2c = y[:,1]

# %%
tt = t
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, sharex='col',
                                                       sharey='row',figsize =(10,6))
ax1.plot(tt, y1, c = 'k') 
ax1.set_title('Amortiguado', fontsize = 14)
ax1.set_ylabel('Posición', fontsize = 14)
ax2.plot(tt, y1s, c = 'b') 
ax2.set_title('Sobreamortiguado', fontsize = 14)
ax3.plot(tt, y1c, c = 'r') 
ax3.set_title('Crítico', fontsize = 16)
ax4.plot(tt, y2, c = 'k')
ax4.set_ylabel('Velocidad', fontsize = 14)
ax4.set_xlabel('tiempo', fontsize = 14)
ax5.plot(tt, y2s, c = 'b')
ax5.set_xlabel('tiempo', fontsize = 14)
ax6.plot(tt, y2c, c = 'r')
ax6.set_xlabel('tiempo', fontsize = 14)
plt.show()

# %% [markdown]
# ## $y_0$ = [-1, -1]

# %%
# Subamortiguado

# Definimos los parámetros k, m y c
k, m, c = 3, 1, 0.5

# Función f(y,t) que vamos a integrar
def amortiguado(y,t,k,m,c):
    y1 = y[-1]
    y2 = y[-1]
    return np.array([y2, -(k/m)*y1-(c/m)*y2])

# Condiciones iniciales
y0 = np.array([-1,-1])

# Especificamos los puntos de tiempo donde queremos la solución
t = np.linspace(0, 30, 300)

# Solución numérica
y = odeint(amortiguado, y0, t, args=(k,m,c))

omega0 = (k/m)**0.5
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 > Gamma**2

# Sobreamortiguado
# Nuevas constantes 
k = .1 # Constante del muelle
m = 1.0   # Masa
c = 1 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2<Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1s = y[:,-1]
y2s = y[:,-1]


# Amortiguamiento crítico
# Nuevas constantes
k = .0625 # Constante del muelle
m = 1.0   # Masa
c = .5 # Constante de amortiguación
omega0 = np.sqrt(k/m)
Gamma = c/(2*m)
omega0**2, Gamma**2
omega0**2 == Gamma**2
# Simular
y = odeint(amortiguado, y0, t, args=(k,m,c))
y1c = y[:,-1]
y2c = y[:,-1]

# %%
tt = t
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, sharex='col',
                                                       sharey='row',figsize =(10,6))
ax1.plot(tt, y1, c = 'k') 
ax1.set_title('Amortiguado', fontsize = 14)
ax1.set_ylabel('Posición', fontsize = 14)
ax2.plot(tt, y1s, c = 'b') 
ax2.set_title('Sobreamortiguado', fontsize = 14)
ax3.plot(tt, y1c, c = 'r') 
ax3.set_title('Crítico', fontsize = 16)
ax4.plot(tt, y2, c = 'k')
ax4.set_ylabel('Velocidad', fontsize = 14)
ax4.set_xlabel('tiempo', fontsize = 14)
ax5.plot(tt, y2s, c = 'b')
ax5.set_xlabel('tiempo', fontsize = 14)
ax6.plot(tt, y2c, c = 'r')
ax6.set_xlabel('tiempo', fontsize = 14)
plt.show()
